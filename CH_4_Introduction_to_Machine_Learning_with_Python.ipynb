# %% [markdown]
# <a href="https://colab.research.google.com/github/hiiya74/Sem-4-Python/blob/main/CH_4_Introduction_to_Machine_Learning_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# Cloning into 'SEM-4-Python-2'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
data=pd.DataFrame({'Length':room_length,'Breadth':room_breadth,'Type':room_type})
data
# Out:
#    Length  Breadth    Type
# 0      18       20     Big
# 1      20       20  Normal
# 2      10       10     Big
# 3      12       11  Normal
# 4      18       19     Big
# 5      11       18  Normal

# %%
import pandas as pd
room_length=[18,20,10,12,18,11]
room_breadth=[20,20,10,11,19,18]
room_type=['Big','Normal','Big','Normal','Big','Normal']

# %%
data['Area']=data['Length']*data['Breadth']
data
# Out:
#    Length  Breadth    Type  Area
# 0      18       20     Big   360
# 1      20       20  Normal   400
# 2      10       10     Big   100
# 3      12       11  Normal   132
# 4      18       19     Big   342
# 5      11       18  Normal   198

# %%
pd.get_dummies(data)
# Out:
#    Length  Breadth  Area  Type_Big  Type_Normal
# 0      18       20   360      True        False
# 1      20       20   400     False         True
# 2      10       10   100      True        False
# 3      12       11   132     False         True
# 4      18       19   342      True        False
# 5      11       18   198     False         True

# %%
data=pd.get_dummies(data,drop_first=True)
data
# Out:
#    Length  Breadth  Area  Type_Normal
# 0      18       20   360        False
# 1      20       20   400         True
# 2      10       10   100        False
# 3      12       11   132         True
# 4      18       19   342        False
# 5      11       18   198         True

# %%
import pandas as pd
apartment_area=[4720,2434,4368,3969,6142,7912]
apartment_price=[2360000,1215000,21840000,19840000,30771000,39560000]
data1=pd.DataFrame({'Area':apartment_area,'Price':apartment_price})
data1
# Out:
#    Area     Price
# 0  4720   2360000
# 1  2434   1215000
# 2  4368  21840000
# 3  3969  19840000
# 4  6142  30771000
# 5  7912  39560000

# %%
import numpy as np
data1['Price']=np.where(data1['Price']>3000000,'High',np.where(data1['Price']<2000000,'Low','Medium'))
data1
# Out:
#    Area   Price
# 0  4720  Medium
# 1  2434     Low
# 2  4368    High
# 3  3969    High
# 4  6142    High
# 5  7912    High

# %% [markdown]
# ***PB-170 You've been given a dataset with apartment area and price information. There's a noticeable non-linear relationship between
# assuming that dataset has two columns named area and price.
# area and price. To address this you intend to categorize them into 'High', 'Medium', and 'Low' groups. Prices above $3,000,000
# are 'High', below $2,000,000 are 'Low', and between $2,000,000 and $3,000,000 are 'Medium'. Write a code to achieve ***

# %%
import pandas as pd
import numpy as np
a={
    'area': [500, 750, 1000, 1200, 1500],
    'price': [1500000, 2500000, 3000000, 3500000, 1800000]
}
df=pd.DataFrame(a)
df['category']=np.where(df['price']>3000000,'high',
               np.where(df['price']<2000000,'low','medium'))
df
# Out:
#    area    price category
# 0   500  1500000      low
# 1   750  2500000   medium
# 2  1000  3000000   medium
# 3  1200  3500000     high
# 4  1500  1800000      low

# %% [markdown]
# ***QB-171 In a survey dataset, you have a column representing participants' ages. You want to categorize ages into 'Young', 'Middle-aged',
# and 'Elderly' groups. Ages below 30 are 'Young', ages between 30 and 60 are 'Middle-aged', and ages above 60 are 'Elderly' Write a code to achieve this assuming the dataset has a column named ‘age’.***

# %%
import pandas as pd
import numpy as np
data={'age':[25,35,45,55,65,75,85]}
df=pd.DataFrame(data)
df['age_group']=np.where(df['age']<30,'young',
                np.where(df['age']>60,'middle-aged','elderly'))
df
# Out:
#    age    age_group
# 0   25        young
# 1   35      elderly
# 2   45      elderly
# 3   55      elderly
# 4   65  middle-aged
# 5   75  middle-aged
# 6   85  middle-aged

# %% [markdown]
# ***PB-172  In a customer dataset, you have a column representing customer incomes. You want to categorize incomes into 'Low', 'Medium',
# and 'High' groups. Incomes below 30000 are 'Low', incomes between 30000 and 70000 are 'Medium', and incomes above 70000 are 'High'. Write a code to achieve this assuming the dataset has a column named 'income'.***

# %%
import pandas as pd
import numpy as np
data1={'income': [25000, 32000, 45000, 60000, 75000, 80000, 100000]}
df=pd.DataFrame(data1)
df['income_group']=np.where(df['income']<30000,'low',
                   np.where(df['income']>70000,'High','Medium'))
df
# Out:
#    income income_group
# 0   25000          low
# 1   32000       Medium
# 2   45000       Medium
# 3   60000       Medium
# 4   75000         High
# 5   80000         High
# 6  100000         High
